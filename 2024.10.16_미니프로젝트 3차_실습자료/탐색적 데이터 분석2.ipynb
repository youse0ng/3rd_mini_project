# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import joblib
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
data_train = pd.read_csv('../2024.10.16_미니프로젝트 3차_실습자료\data01_train.csv')
data_test = pd.read_csv('../2024.10.16_미니프로젝트 3차_실습자료\data01_test.csv')
data_is_dy_train = joblib.load('../2024.10.16_미니프로젝트 3차_실습자료\Is_Dynamic_DF.pkl')
feature = pd.read_csv('../2024.10.16_미니프로젝트 3차_실습자료/features.csv')
data_test.drop(columns='subject',inplace=True)
data_train.drop(columns='subject',inplace=True)

# %%
data = pd.read_csv('../2024.10.16_미니프로젝트 3차_실습자료\data01_train.csv')
data = data.drop(columns='subject')

LAYING = data.loc[data['Activity']=='LAYING']
SITTING = data.loc[data['Activity']=='SITTING']
WALKING = data.loc[data['Activity']=='WALKING']
WALKING_UPSTAIRS = data.loc[data['Activity']=='WALKING_UPSTAIRS']
WALKING_DOWNSTAIRS = data.loc[data['Activity']=='WALKING_DOWNSTAIRS']
STANDING = data.loc[data['Activity']=='STANDING']
IS_DYNAMIC = data_is_dy_train.loc[data_is_dy_train['Activity']==1]
IS_STATIC = data_is_dy_train.loc[data_is_dy_train['Activity']==0]

LAYING.reset_index(inplace=True)
SITTING.reset_index(inplace=True)
WALKING.reset_index(inplace=True)
WALKING_UPSTAIRS.reset_index(inplace=True)
WALKING_DOWNSTAIRS.reset_index(inplace=True)
STANDING.reset_index(inplace=True)

# %%
IS_DYNAMIC
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 3              0.289795          -0.035536          -0.150354
# 4              0.394807           0.034098           0.091229
# 5              0.330708           0.007561          -0.061371
# 6              0.121465          -0.031902          -0.005196
# 12             0.303885           0.002768          -0.038613
# ...                 ...                ...                ...
# 5868           0.277709          -0.053919          -0.098746
# 5869           0.252496          -0.009773          -0.118293
# 5873           0.264961          -0.034719          -0.088140
# 5877           0.191568           0.013328          -0.105174
# 5879           0.212787          -0.048130          -0.121001
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 3            -0.231727         -0.006412         -0.338117         -0.273557
# 4             0.088489         -0.106636         -0.388502         -0.010469
# 5            -0.215760          0.101075          0.072949         -0.269857
# 6            -0.152198         -0.113104         -0.239423         -0.202401
# 12           -0.168656          0.190336         -0.140473         -0.205134
# ...                ...               ...               ...               ...
# 5868         -0.589970         -0.076626         -0.500837         -0.605474
# 5869         -0.155168         -0.244513         -0.044524         -0.244367
# 5873         -0.368158         -0.074514         -0.229606         -0.394387
# 5877         -0.126969         -0.121729         -0.327480         -0.192523
# 5879         -0.041373          0.052449         -0.585361         -0.100714
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 3             0.014245         -0.347916          0.008288  ...
# 4            -0.109680         -0.346372          0.584131  ...
# 5             0.060060          0.101298         -0.019263  ...
# 6            -0.164698         -0.247099          0.114668  ...
# 12            0.101144         -0.120572         -0.000818  ...
# ...                ...               ...               ...  ...
# 5868         -0.142798         -0.506696         -0.533485  ...
# 5869         -0.229509         -0.042199          0.291682  ...
# 5873         -0.082437         -0.243525         -0.261087  ...
# 5877         -0.109923         -0.295286          0.078644  ...
# 5879          0.023353         -0.554707          0.219814  ...
#
#       fBodyBodyGyroJerkMag-skewness()  fBodyBodyGyroJerkMag-kurtosis()  \
# 3                           -0.004012                        -0.408956
# 4                           -0.157832                        -0.563437
# 5                           -0.599906                        -0.887024
# 6                           -0.371055                        -0.775779
# 12                          -0.037750                        -0.329728
# ...                               ...                              ...
# 5868                         0.029201                        -0.268237
# 5869                        -0.475800                        -0.752980
# 5873                         0.198624                        -0.046157
# 5877                        -0.622617                        -0.879215
# 5879                         0.196921                        -0.053556
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 3                       -0.255125                              0.612804
# 4                       -0.044344                             -0.845268
# 5                       -0.030645                             -0.852091
# 6                        0.445206                             -0.003487
# 12                      -0.040030                              0.257252
# ...                           ...                                   ...
# 5868                    -0.076922                              0.706620
# 5869                     0.619246                             -0.684483
# 5873                     0.037517                             -0.903692
# 5877                     0.721718                              0.623151
# 5879                     0.260880                              0.551742
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 3                             0.747381                             -0.072944
# 4                            -0.974650                             -0.887846
# 5                            -0.500195                              0.306091
# 6                            -0.940185                              0.041387
# 12                            0.076091                             -0.123425
# ...                                ...                                   ...
# 5868                         -0.954969                             -0.324779
# 5869                          0.924623                             -0.353041
# 5873                          0.614933                             -0.610918
# 5877                          0.866858                             -0.445660
# 5879                         -0.943773                             -0.862899
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 3                -0.695819              0.287154              0.111388
# 4                -0.705029              0.264952              0.137758
# 5                -0.552729              0.253885              0.291256
# 6                -0.886603              0.173338             -0.005627
# 12               -0.752882              0.266729              0.045692
# ...                    ...                   ...                   ...
# 5868             -0.691663              0.153974             -0.196833
# 5869             -0.775518              0.253218              0.013216
# 5873             -0.601604              0.335996              0.156518
# 5877             -0.690278              0.303194             -0.044188
# 5879             -0.718009              0.292856              0.024920
#
#       Activity
# 3            1
# 4            1
# 5            1
# 6            1
# 12           1
# ...        ...
# 5868         1
# 5869         1
# 5873         1
# 5877         1
# 5879         1
#
# [2647 rows x 562 columns]
